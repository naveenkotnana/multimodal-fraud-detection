# %%
 # Check python
# !python --version

# Core libs
# !pip install -q pandas numpy scikit-learn xgboost torch transformers faker pyarrow
# Out:
# Python 3.12.12
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 23.1 MB/s eta 0:00:0000:010:01

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os

BASE = "/content/drive/MyDrive/fraud-detection"
folders = [
    "data/raw",
    "data/synthetic",
    "data/processed",
    "models/artifacts",
    "notebooks",
    "scripts",
    "api",
    "dashboard"
]

for f in folders:
    os.makedirs(os.path.join(BASE, f), exist_ok=True)
